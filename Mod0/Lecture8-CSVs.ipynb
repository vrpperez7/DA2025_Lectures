# %% [markdown]
# # **Code-Along: Handling Encoding and Mixed Delimiters in CSV Files**
#
# In this notebook, you will learn how to:
# 1. Read a CSV file with a specific encoding.
# 2. Handle mixed delimiters in a CSV file.
# 3. Use Python's built-in tools (`open()` and `csv` module) to process the file.
#
# ---
#
# ## **Scenario**
# You are working with a CSV file that contains data about public transportation usage. The file:
# - Uses **UTF-8 encoding**.
# - Contains **mixed delimiters** (commas and semicolons).
# - Includes a header row.
#
# Your task is to:
# 1. Read the file correctly.
# 2. Extract specific information.
# 3. Perform basic analysis on the data.
#
# ---
#
# ## **Dataset: public_transport.csv**
#
# **File Contents:**
#
# - Station
# - Daily Ridership (how many people rode)
# - City

# %% [markdown]
# ## **Part 1: Reading the CSV File**
#
# ### Task:
# 1. Open the file `public_transport.csv` using the `open()` function and the `with` statement.
# 2. Use the `csv.reader()` function to read the file.
# 3. Handle the mixed delimiters (commas and semicolons) by splitting the rows manually.
#
#
# <b> Instructor notes ONLY
#
# Explain packages here (pull up CSV python documentation)
# Explain the with syntax (automatically closes the file after reading it)
# Make sure they understand the for loop here </b>

# %%
# import the csv package 

import csv

# %%
# Open the CSV file with UTF-8 encoding
with open('data/public_transport.csv', 'r', encoding='utf-8') as file:
    reader = csv.reader(file)
    
    # Iterate through the rows
    for row in reader:
        # The first column is the station name
        station = row[0]
        
        # The second column contains "Daily_Ridership;City", so we split it by the semicolon
        ridership, city = row[1].split(';')  # Correctly access the second element of the list and split it
        
        # Print the extracted data
        print(f"Station: {station}, Daily Ridership: {ridership}, City: {city}")
# Out:
# Station: Station, Daily Ridership: Daily_Ridership, City: City
# Station: Times Square, Daily Ridership: 500000, City: New York
# Station: Grand Central, Daily Ridership: 300000, City: New York
# Station: Union Station, Daily Ridership: 200000, City: Washington D.C.
# Station: Hollywood/Highland, Daily Ridership: 150000, City: Los Angeles

# %% [markdown]
# ## Part 2: Extracting Specific Information
# ### Task:
# - Skip the header row.
# - Print only the station names and their corresponding cities.
#
# <b> Instructor Notes ONLY
#
# Bring up indexing here and the function next() which is specific to CSV package
#
# </b>

# %%
# Open the CSV file with UTF-8 encoding
with open('data/public_transport.csv', 'r', encoding='utf-8') as file:
    reader = csv.reader(file)
    
    # Skip the header row
    next(reader)
    
    # Print station names and cities
    for row in reader:
        station = row[0]
        city = row[1].split(';')[1]  # Split the second column and get the city
        print(f"Station: {station}, City: {city}")
# Out:
# Station: Times Square, City: New York
# Station: Grand Central, City: New York
# Station: Union Station, City: Washington D.C.
# Station: Hollywood/Highland, City: Los Angeles

# %% [markdown]
# ## Part 3: Basic Analysis
#
# ### Task:
# - Count the total number of stations.
# - Calculate the total daily ridership across all stations.
#
# <b> Instructor Notes ONLY
#
# Be sure to explain the += and type casting (changing a variable from a float to integer or string to integer etc) </b>

# %%
# Initialize variables
station_count = 0
total_ridership = 0

# Open the CSV file with UTF-8 encoding
with open('data/public_transport.csv', 'r', encoding='utf-8') as file:
    reader = csv.reader(file)
    
    # Skip the header row
    next(reader)
    
    # Iterate through the rows
    for row in reader:
        station_count += 1
        ridership = int(row[1].split(';')[0])  # Convert ridership to an integer
        total_ridership += ridership

# Print the results
print("Total Stations:", station_count)
print("Total Daily Ridership:", total_ridership)
# Out:
# Total Stations: 4
# Total Daily Ridership: 1150000
