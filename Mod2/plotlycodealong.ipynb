# %%
import plotly.express as px
df = px.data.gapminder().query("year == 2007")
px.scatter(df, x="gdpPercap", y= "lifeExp", size="pop", color="continent",
           hover_name="country", log_x=True)
                                #log_x scales the data to be able to visualize

# %%
import pandas as pd

# Sample data: Monthly app visitors
df_line = pd.DataFrame({
    'Month': ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun'],
    'Visitors': [1200, 1500, 1600, 1400, 1700, 1800]
})

fig = px.line(df_line, x= 'Month', y= 'Visitors', title= 'Monthly App Visitors')
fig.show()

# %%
df_bar = pd.DataFrame({
    'Category': ['Shoes', 'Accessories', 'Outerwear', 'Tops', 'Bottoms'],
    'Sales': [24000, 14000, 18000, 22000, 20000]
})

fig = px.bar(df_bar, x='Category', y= 'Sales', title= 'Sales by Product Category',
             text= 'Sales')
fig.update_traces(textposition='outside')
fig.show()
